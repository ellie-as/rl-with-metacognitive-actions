# %%
# !python experiment.py

# %%
# !python baselines_comparison.py > baselines_comparison_log.txt

# %%
# !python data_valuation_comparison.py --episodes 10 > data_valuation_comparison_log.txt

# %%
# !python data_value_vs_novelty.py --novelty-metric distance > data_value_vs_novelty_log.txt
